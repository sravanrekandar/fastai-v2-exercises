# %%
# !pip install -Uqq fastbook

# %%
from fastbook import *
from fastai.vision.widgets import *

# %%
key = os.environ.get('AZURE_SEARCH_KEY', 'b7efb78f4a214dcd8404684a56293762')

# %%
beagle_dog_results = search_images_bing(key, 'beagle dog')
beagle_dog_image_urls = beagle_dog_results.attrgot('content_url')
len(beagle_dog_image_urls)
# Out:
# 150

# %%
dest = 'images/beagle2.jpg'
download_url(beagle_dog_image_urls[0], dest)

beagle_image = Image.open(dest)
beagle_image.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7FF4B648CFD0>

# %%
dog_types = 'beagle','dobar man','dolmation'
dogs_path = Path('dogs')
if not dogs_path.exists():
    dogs_path.mkdir()
    for d in dog_types:
        dog_dest = (dogs_path/d)
        dog_dest.mkdir(exist_ok=True)
        dog_results = search_images_bing(key, f'{d} dog')
        download_images(dog_dest, urls=dog_results.attrgot('content_url'))

dog_files = get_image_files(dogs_path)
dog_files
# Out:
# (#439) [Path('dogs/beagle/00000000.jpg'),Path('dogs/beagle/00000001.jpg'),Path('dogs/beagle/00000002.jpeg'),Path('dogs/beagle/00000003.jpg'),Path('dogs/beagle/00000004.jpg'),Path('dogs/beagle/00000006.jpg'),Path('dogs/beagle/00000007.jpeg'),Path('dogs/beagle/00000008.jpg'),Path('dogs/beagle/00000009.jpeg'),Path('dogs/beagle/00000010.jpg')...]

# %%
failed_dog_downloads = verify_images(dog_files)
print(f'There are {len(failed_dog_downloads)} failed dog downloads')
# TODO We get an error when we run the bellow unlink script more than once.
# Put a check to call the Path.unlink only if the image is not unlinked yet
# if len(failed_dog_downloads):
#     failed_dog_downloads.map(Path.unlink)

failed_dog_downloads
# Out:
# There are 0 failed dog downloads
# (#0) []

# %%
# Creating a data block
dogs_data_block = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dog_data_loaders = dogs_data_block.dataloaders(dogs_path)

# %%
# See samples from validation set
dog_data_loaders.valid.show_batch(max_n=4, nrows=1)

# %%
# See samples from training set
dog_data_loaders.train.show_batch(max_n=4, nrows=1)

# %%
# By default Resize crops the images to fit a square shape of the size requested,
# using the full width or height. This can result in losing some important details.
# Alternatively, you can ask fastai to pad the images with zeros (black),
# or squish/stretch them:

dogs_data_block = dogs_data_block.new(item_tfms=Resize(128, ResizeMethod.Squish))
dog_data_loaders = dogs_data_block.dataloaders(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a582a6c27e3b> in <module>
#       5
#       6 dogs_data_block = dogs_data_block.new(item_tfms=Resize(128, ResizeMethod.Squish))
# ----> 7 dog_data_loaders = dogs_data_block.dataloaders(path)
#
# NameError: name 'path' is not defined

# %%
# Sample images from Validation set after resizing
dog_data_loaders.valid.show_batch(max_n=4, nrows=1)

# %%
# Sample images from Training set after resizing
dog_data_loaders.train.show_batch(max_n=4, nrows=1)

# %%
dogs_data_block = dogs_data_block.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dog_data_loaders = dogs_data_block.dataloaders(path)

# %%
# Sample images from Validation set after applying black padding 
dog_data_loaders.valid.show_batch(max_n=4, nrows=1)

# %%
# Sample images from Training set after applying black padding 
dog_data_loaders.train.show_batch(max_n=4, nrows=1)

# %%
# Applying crop method instead of resize method
dogs_data_block = dogs_data_block.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dog_data_loaders = dogs_data_block.dataloaders(path)

# This method is using Data augmentation. Random variations of each image would be created

# %%
# Sample images from Validation set after applying crop
dog_data_loaders.valid.show_batch(max_n=4, nrows=1, unique=True)

# %%
# Sample images from Training set after applying crop
dog_data_loaders.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
# Data augmentation beyond default
dogs_data_block = dogs_data_block.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dog_data_loaders = dogs_data_block.dataloaders(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-ba9e1e9e4077> in <module>
#       1 # Data augmentation beyond default
#       2 dogs_data_block = dogs_data_block.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
# ----> 3 dog_data_loaders = dogs_data_block.dataloaders(path)
#
# NameError: name 'path' is not defined

# %%
# Sample Image augmented variations of Validation Data Set
dog_data_loaders.valid.show_batch(max_n=8, nrows=2, unique=True)

# %%
# Sample Image augmented variations of Training Data Set
dog_data_loaders.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# # Training Your Model, and Using It to Clean Your Data¶
# Time to use the same lines of code as in <
#
# We don't have a lot of data for our problem (150 pictures of each sort of bear at most), so to train our model, we'll use RandomResizedCrop with an image size of 224 px, which is fairly standard for image classification, and default aug_transforms:

# %%
dogs_data_block = dogs_data_block.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dog_data_loaders = dogs_data_block.dataloaders(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a67a6d20cdbd> in <module>
#       2     item_tfms=RandomResizedCrop(224, min_scale=0.5),
#       3     batch_tfms=aug_transforms())
# ----> 4 dog_data_loaders = dogs_data_block.dataloaders(path)
#
# NameError: name 'path' is not defined

# %% [markdown]
# We can now create our Learner and fine-tune it in the usual way:

# %%
learn = cnn_learner(dog_data_loaders, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.508613</td>
#       <td>0.250410</td>
#       <td>0.091954</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.223831</td>
#       <td>0.007684</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.129852</td>
#       <td>0.004763</td>
#       <td>0.000000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.089824</td>
#       <td>0.008072</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.068480</td>
#       <td>0.018511</td>
#       <td>0.011494</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Creating confusion matrix
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
# Exporting Model
# When you call export, by default, fastai will save a file called "export.pkl"
# We are passing file name here
learn.export(fname='dog_learner.pkl')

# %% [markdown]
# Let's check that the file exists, by using the ls method that fastai adds to Python's Path class:

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#2) [Path('dog_learner.pkl'),Path('export.pkl')]

# %%
file = open('dog_learner.pkl') 
file
# Out:
# <_io.TextIOWrapper name='dog_learner.pkl' mode='r' encoding='UTF-8'>

# %%
Path('dog_learner.pkl').stat()
# Out:
# os.stat_result(st_mode=33188, st_ino=281019490, st_dev=64768, st_nlink=1, st_uid=0, st_gid=0, st_size=47007497, st_atime=1600515495, st_mtime=1600526660, st_ctime=1600526660)

# %%
bytes = Path('dog_learner.pkl').stat().st_size
mega_bytes = 0.000001 * bytes
print(f'Model size = {round(mega_bytes)} MB')
# Out:
# Model size = 47 MB

# %% [markdown]
# # Using the trained model

# %%
# We can use the 'learn' object from above. But to demostrate the flow, 
# we are loading the model
learn_inference = load_learner(path/'dog_learner.pkl')

# %%
# Test input - We had downloaded this in the beginning
dest = 'images/beagle2.jpg'
# download_url(beagle_dog_image_urls[0], dest)

# beagle_image = Image.open(dest)
beagle_image.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7FF49DAEDB20>

# %%
dog_prediction = learn_inference.predict('images/beagle2.jpg')
dog_prediction
# Out:
# ('beagle', tensor(0), tensor([1.0000e+00, 3.6459e-09, 1.8689e-07]))

# %%
dog_prediction[0]
# Out:
# 'beagle'

# %%
learn_inference.dls.vocab
# Out:
# (#3) ['beagle','dobar man','dolmation']

# %% [markdown]
# # Creating a Web Application to serve the Learner(Model)

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
btn_upload.data
# Out:
# [b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x13\x12\x12\x15\x12\x12\x13\x15\x16\x15\x15\x16\x18\x19\x18\x16\x18\x17\x15\x15\x18\x16\x15\x19\x16\x17\x18\x16\x18\x18\x18\x18\x1d( \x18\x1a%\x1f\x18\x17!1!%)+...\x18\x1f383,7(-.+\x01\n\n\n\x0e\r\x0e\x1a\x10\x10\x1b-% %-------/------------------------------------------\xff\xc0\x00\x11\x08\x00\xa5\x011\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x01\x04\x03\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x03\x05\x06\x02\x04\x07\x08\xff\xc4\x00@\x10\x00\x01\x03\x02\x03\x06\x04\x04\x03\x06\x05\x03\x05\x00\x00\x00\x01\x00\x02\x11\x03!\x04\x121\x05\x06AQaq\x13"\x81\x91\x072\xa1\xb1\xc1\xd1\xf0\x14#BRb\xe1r\x82\x92\xc2\xf13\xa2\xb2\x15$Ccs\xff\xc4\x00\x19\x01\x00\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\xff\xc4\x00#\x11\x00\x02\x02\x03\x01\x00\x01\x04\x03\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03!1\x12\x04\x13"AQ\x14#q\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xecHB\x16\x84\x82\x10\x84\x00.!\xf1\xd2\x8b\x99\x89\xa7Q\xa4\x80\xfap`\x91v\x93\xf8\x10\xbbz\xe5_\x1d\xf0sF\x95H\xf9\\D\xf7\x16\x952\x1czp\xca\xae\x9b\xf1?\x9a\xee\x7f\x00v\xb6l5l#\x8f\x9a\x8b\xf3\xb4\x7f\xf5\xd4\xd6;8\x1f\xf5.\x18\x04\xabG\xc3\xcd\xe0\x18\x0cu:\xee?\xbbt\xd3\xab\xfe\x07q\xff\x00)\rw\xa1I\x03Z=@\x84\x80\x83qpt=\x12\xa6@!\x08@\t\t!d\x84\xc0\xc5\ta\x10\x90\x08\x84\xb0\x88L\x04BXD \x04BXD \x04\x84%\x84BC\xb3\x18D%\x84B\x02\xc4\x84BT ,\xc1\x0b2\xb1@\xc4B\x10\x80\x10\xa1*B\x80\x04!\x08\x00B\x10\x80\x04!\x08\x01\xe4!\n\x80\x10\x84 \x01U>&\xe0<m\x9fZ\x04\x96\x0c\xde\x83_\xcf\xd1Z\xd6\x15\xe9\x874\xb4\x89\x0e\x04\x11\xdd!\x1e<2\n\xc0uV\x8d\xef\xd8\xdf\xb3b\xea\xd2\x88\x19\x89o"\xd3q\xe9\xf9(J\xb4\xfa),\xef\xdf\x07\xb7\x97\xf6\xac\x13h<\xfe\xfb\x0e\xd0\xc3\xcd\xd4\xc5\x98\xeb\xf4\xb1\xed\xd5_\x97\x96\xb7Sm\xd4\xc1b\x19Z\x99\xbbM\xdb\xc1\xcd:\xb4\xf4+\xba\xd7\xf8\x9f\xb3X\xc69\xd5\xfc\xceh>\x1b\x1a\xea\x8fl\xea\x1d\x94CH\xeaUt\x86\x8b\x82\x17&\xda\xff\x00\x1b\xa9\xb6F\x1b\n\xf7ruW\x06\x0e\xe1\xac\xccO\xa9\n\xa1\xb4\xfe-\xed*\xb3\x92\xa5:#\x87\x87L{\x13S7\xd2\x12\xb4\x1eY\xe8\x84/,T\xdf\x9d\xa4L\x9cv#\xd1\xf9G\xd3E\xb7\x81\xf8\x8f\xb5)\x90\x7fk{\xbaTk*\x03\xee\xd9\xfa\x82\x8bC\xf2\xcfN!q\xfd\xdf\xf8\xd0\xe8\x03\x1b\x87\x9d?y@\xfdM7\x9f\xb3\xbd\x17N\xd8\x1b\x7f\r\x8d\xa6*a\xaa\xb5\xe3\x88\xd1\xed<\x9c\xc3v\x9e\xe9\x93D\x92\x12\xc2HH\x01\ta\x10\x80\x11\t\xbc^)\x94\x98jTpkF\xa4\xfd\x873\xd1R\xf6\x9e\xf5\xd6\xaaK0\xed\xf0\xdb\xa6g|\xee\xed\x1f/\xdd)I.\x95\x18\xb9p\xb7cv\x8d*?\xf5\x1e\x1b\xc8jO`.T&#{\x87\xff\x00\x15\n\xaf\x1f\xcca\xad\xfcO\xd1W\xf08\t%\xce9\x8c\xc9%\xc1\xd0x\xc9\xd7\xddl\xe3\x19\x90\x10\x0f\x0e\x11n=\xe1r\xcf\xe4\xd7\x0e\xa8|e\xf9%[\xbe-\x1f=\'7\xfc\xcd6\xfa\'\xd9\xbdT\xc9\x8f\x0e\xa4s\x19O\xe2\xb9~\xd2\xc4\xbc\xba\xc6\xdd\xfe\xa3\x8f\xb7\xfc\xeda\xf1\xeeh\x00\xdex\xebh\xe9\xa7};)\xfeK/\xf8\xb1:\xce\x1fi\xd2y\x80\xe8<\x9d\xe5?]V\xe4.UGmK\xb2:\xd1\x1a\xf6\xb1\xec\xac\xdb?m=\x83\\\xc2c+\xa7\xfe\xd3\xaf\xddm\x0c\xea]0\x9f\xc7q\xe1nB\xd7\xc1c\x99T[[H:\x89[\x0b{0v\x8cHH\xb2+\x14\x0c\x12\x14\xa9\n\x00\x10\x84 \x01\x08B\x00\x10\x84 \x07J\x02D*\x03$$J\x80\x04\x04 $&r\xbf\x8c\xfb\xbd\x99\xad\xc50]\xb6w\xf8{\xf7\\x\xb6\xd6\xf6^\xad\xda\x98\x16\xd7\xa4\xfao\x00\x874\x83=B\xf2\xc6\xd9\xa2)U\xa9M\xaf\x0e\xca\xe74\x10l@1",T\xb2\xe3\xb3B\xbdx\xb0>\xbf\x82l>\xdf}Sq~)\xc0\xc5,\xa1\x0ft\x84qN2\x95\x93\xa6\x88\xe3\x01\x00j\x06\x13<\xfa\xa7\xe9RN\xd3\xa0g\xfbG\xfc\xad\xb6\xd2\x02\xfc\xb5\n\x92\x13cl\xc3\xc6\xb6\xe2\xb6\xf05\xeaQ{j\xd0\xa8\xeau\x1a>v\x98"\xfa\x18\xb1\x16\xd0\xda\xc9(\xdc\xad\x82\xf6\x8d9\x1b[\xd9ZD\xb6t\xfd\xdd\xf8\xaa\xe8kqt\x81"\x01\xabN\xd3x\x92\xce\x07\xb1\xf4\x0b\xa5l\xcd\xa5K\x10\xc1R\x8b\xda\xf6\x9eD\x18\xe3\x04p+\xcc\x8d\xc4\x81\xd0s\x82G\xb8V\xcd\xc9\xc1\xe2\x1d]\xae\xc2\xd5s\r\xb3\x18\x8b\x7fSO\xcc\xd3\xc3\xb24E\x1d\xe5jmM\xa0\xcc=3R\xa1\x804\x1c\\y4q*\x07jo\'\xec\xc3\xc3\'\xc6\xad\x17\x03\xca\xc6q\x97\x11\xf6\xe8\xa98\x8cc\xf15\rZ\xef\xceD\x86\xb6\x0eVt`\x06\x07\xad\x ...

# %%
uploaded_dog_image = PILImage.create(btn_upload.data[-1])
uploaded_dog_image
# Out:
# PILImage mode=RGB size=305x165

# %%
# Use output widget to display
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(uploaded_dog_image.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
# Predicting...
prediction,prediction_idx,probabilities = learn_inference.predict(uploaded_dog_image)

# %%
# Use Label to display
label_prediction = widgets.Label()
label_prediction.value = f'Prediction: {prediction}; Probability: {probabilities[prediction_idx]:.04f}'
label_prediction
# Out:
# Label(value='Prediction: beagle; Probability: 1.0000')

# %%
# We'll need a button to do the classification. It looks exactly like the upload button:
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
# We'll also need a click event handler;
# that is, a function that will be called when it's pressed.
# We can just copy over the lines of code from above:
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inference.predict(img)
    label_prediction.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()
VBox([
    widgets.Label('Select your bear!'),
    btn_upload,
    btn_run,
    out_pl,
    label_prediction
])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…
